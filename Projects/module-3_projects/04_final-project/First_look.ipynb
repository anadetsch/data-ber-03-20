# %%
import pandas as pd
import numpy as np

# %%
country = pd.read_csv("WDI_csv/WDICountry.csv")

# %%
country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit Special Notes                     Region  \
# 0           AW   Aruban florin           NaN  Latin America & Caribbean
# 1           AF  Afghan afghani           NaN                 South Asia
# 2           AO  Angolan kwanza           NaN         Sub-Saharan Africa
# 3           AL    Albanian lek           NaN      Europe & Central Asia
# 4           AD            Euro           NaN      Europe & Central Asia
#
#           Income Group WB-2 code  ...    Government Accounting concept  \
# ...

# %%
country.dtypes
# Out:
# Country Code                                          object
# Short Name                                            object
# Table Name                                            object
# Long Name                                             object
# 2-alpha code                                          object
# Currency Unit                                         object
# Special Notes                                         object
# Region                                                object
# Income Group                                          object
# WB-2 code                                             object
# National accounts base year                           object
# National accounts reference year                      object
# SNA price valuation                                   object
# Lending category                                      object
# Other groups                                          object
# ...

# %%
country_series = pd.read_csv("WDI_csv/WDICountry-Series.csv")

# %%
country_series.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
# 3         ABW        IT.CEL.SETS
# 4         ABW     IT.CEL.SETS.P2
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Sources: Estimated based on UN Energy Statisti...         NaN
# 1               Sources: UN Energy Statistics (2014)         NaN
# 2               Sources: UN Energy Statistics (2014)         NaN
# 3  Servicio di Telecomunicacion di Aruba (SETAR)....         NaN
# 4  Servicio di Telecomunicacion di Aruba (SETAR)....         NaN

# %%
wdi_data = pd.read_csv("WDI_csv/WDIData.csv")

# %%
wdi_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 2  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 4  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  82.783289  83.120303  83.533457
# 1   NaN   NaN   NaN   NaN   NaN  ...  86.428272  87.070576  88.176836
# 2   NaN   NaN   NaN   NaN   NaN  ...  73.942103  75.244104  77.162305
# ...

# %%
wdi_data["Indicator Name"].value_counts()
# Out:
# Merchandise exports to low- and middle-income economies in Sub-Saharan Africa (% of total merchandise exports)    264
# Source data assessment of statistical capacity (scale 0 - 100)                                                    264
# People using at least basic drinking water services (% of population)                                             264
# Informal employment, male (% of total non-agricultural employment)                                                264
# Secure Internet servers (per 1 million people)                                                                    264
#                                                                                                                  ...
# Specialist surgical workforce (per 100,000 population)                                                            264
# Coverage of social insurance programs in 2nd quintile (% of population)                                           264
# ...
