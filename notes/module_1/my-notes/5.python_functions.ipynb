# %% [markdown]
# ## Functions

# %%
def list2string(lst):
    string = ' '.join(lst)
    return string

to_string = ['John', 'was', 'a', 'man', 'of', 'many', 'talents']

list2string(to_string)
# Out:
# 'John was a man of many talents'

# %%
new_list = ['Ana', 'will', 'find', 'an', 'amazing', 'job']

# %%
list2string(new_list)
# Out:
# 'Ana will find an amazing job'

# %% [markdown]
# ### Global vs. Local Variables
#
# it is important to keep track of which variables are global and which variables are local.
#
# - Global variables: maintain their value outside the functions.
# - Local variables: maintain their value within the function where they are defined

# %%
a = 9

def multiply(number, multiplier = 2):
    b = number * multiplier
    return b

c = multiply(a)

print(a, c)
# Out:
# 9 18

# %%
multiply(5)
# Out:
# 10

# %%
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-67e500defa1b> in <module>
# ----> 1 print(b)
#
# NameError: name 'b' is not defined

# %%
multiply(100, multiplier = 5)
# Out:
# 500

# %% [markdown]
# ### Applying Functions to Data Frames

# %%
import pandas as pd

# %%
data = pd.read_csv('../week_1/data/vehicles_messy.csv')
# Out:
# C:\Anaconda\envs\new_env\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
def get_means(df):
    numeric = df._get_numeric_data()
    means = pd.DataFrame(numeric.mean()).reset_index()
    means.columns = ['Column', 'Mean']
    return means

# %%
mean_df = get_means(data)

mean_df
# Out:
#              Column          Mean
# 0         barrels08     17.532506
# 1        barrelsA08      0.216169
# 2         charge120      0.000000
# 3         charge240      0.023531
# 4            city08     17.941389
# 5           city08U      4.042737
# 6           cityA08      0.520149
# 7          cityA08U      0.327163
# 8            cityCD      0.000406
# 9             cityE      0.184790
# 10           cityUF      0.000706
# 11              co2     61.503713
# 12             co2A      5.349919
# 13  co2TailpipeAGpm     17.771433
# 14   co2TailpipeGpm    473.179736
# 15           comb08     20.195809
# 16          comb08U      4.549751
# 17          combA08      0.581191
# 18         combA08U      0.359027
# 19            combE      0.190575
# 20       combinedCD      0.000335
# 21       combinedUF      0.000691
# 22        cylinders      5.737990
# 23            displ      3.318180
# 24            engId   8860.308961
# 25          feScore     -0.035145
# ...
